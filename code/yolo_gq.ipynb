# %%
import cv2
import numpy as np
from ultralytics import YOLO
from detection import *

# %%
MODEL_PATH = r"..\runs\detect\train3\weights\best.pt"

# %% [markdown]
# ### Get BBOX from YOLO

# %% [markdown]
# ### Tic Tac Toe Video Algorithm

# %%
from detection import process_live_video
process_live_video(1, MODEL_PATH, show_image=False)
# Out:
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [] {('x', 0): 1732723190.5753694}
# [{'label': 'x', 'confidence': 0.9106788635253906, 'cell_index': 0, 'bbox': (225, 127, 292, 194)}] {('x', 0): 1732723190.5753694}
# Board updated: [['x', None, None], [None, None, None], [None, None, None]]
# next move o
# Computer thinking...
# robot enter
# robot doesnt mace moves
# [{'label': 'x', 'confidence': 0.9099951386451721, 'cell_index': 0, 'bbox': (225, 128, 292, 194)}] {('x', 0): 1732723190.5753694}
# ...

# %%
import cv2

def display_live_camera():
    # Initialize the webcam. 0 is the default camera.
    cap = cv2.VideoCapture(1)

    if not cap.isOpened():
        print("Error: Could not open video capture.")
        return

    # Set the width and height if desired
    # cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    # cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

    print("Press 'q' to quit.")

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # if not ret:
        #     print("Failed to grab frame.")
        #     break

        # Optional: Flip the frame horizontally for a mirror effect
        # frame = cv2.flip(frame, 1)

        # Display the resulting frame
        cv2.imshow('Live Camera Feed', frame)

        # Wait for 1 ms and check if 'q' key is pressed to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("Exiting...")
            break

    # When everything done, release the capture and close windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    display_live_camera()

# %% [markdown]
# ## hardcoding cells

# %%
import cv2

# Initialize a list to store points
points = []

# Define the mouse callback function
def click_event(event, x, y, flags, param):
    global points
    if event == cv2.EVENT_LBUTTONDOWN:
        # Store the point
        points.append((x, y))
        print(f"Point {len(points)}: ({x}, {y})")
        
        # Draw a circle at the clicked point
        cv2.circle(img_display, (x, y), 5, (0, 0, 255), -1)
        cv2.putText(img_display, f"{len(points)}", (x + 10, y + 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
        cv2.imshow("Image", img_display)

# Load the image
video = cv2.VideoCapture(1)
    
    # Get grid cells from the first frame for reference
ret, first_frame = video.read()
# image_path = 'path_to_your_image.jpg'  # Replace with your image path
# img = cv2.imread(first_frame)
img = first_frame

if img is None:
    print("Error: Image not found or unable to load.")
    exit()

# Create a copy for display and drawing
img_display = img.copy()

# Create a window and bind the mouse callback function
cv2.namedWindow("Image")
cv2.setMouseCallback("Image", click_event)

print("Instructions:")
print("1. Click on the image to select points.")
print("2. Press 's' to save the points and exit.")
print("3. Press 'q' to exit without saving.")

while True:
    cv2.imshow("Image", img_display)
    key = cv2.waitKey(1) & 0xFF

    if key == ord('s'):
        # Save the points to a file
        with open('selected_points.txt', 'w') as f:
            for idx, point in enumerate(points, start=1):
                f.write(f"Point {idx}: {point}\n")
        print(f"Saved {len(points)} points to 'selected_points.txt'.")
        break
    elif key == ord('q'):
        print("Exiting without saving.")
        break

cv2.destroyAllWindows()

# Optionally, print all points
print("Selected Points:")
for idx, point in enumerate(points, start=1):
    print(f"Point {idx}: {point}")

# %%
points

# %%
point_indices = [0,1,4,5]
cells_coords = [0 for i in range(9)]

for i in range(3):
    first_cell = i
     
    second_cell = first_cell+5

    cells_coords[i] = {
        'x0': points[first_cell][0],
        'y0': points[first_cell][1],
        'x1': points[second_cell][0],
        'y1': points[second_cell][1],
                       }
    
for i in range(4,7):
    first_cell = i
     
    second_cell = first_cell+5

    cells_coords[i-1] = {
        'x0': points[first_cell][0],
        'y0': points[first_cell][1],
        'x1': points[second_cell][0],
        'y1': points[second_cell][1],
                       }
    
for i in range(8,11):
    first_cell = i
     
    second_cell = first_cell+5

    cells_coords[i-2] = {
        'x0': points[first_cell][0],
        'y0': points[first_cell][1],
        'x1': points[second_cell][0],
        'y1': points[second_cell][1],
                       }

# %%
cells_coords
